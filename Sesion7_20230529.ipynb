# %% [markdown]
# # <font color='#2B17B0'>CIENCIA DE DATOS APLICADA A FINANZAS</font>
# Sesión 7, 2022-05-29<br>
# Carlos Crespo Elizondo<br>
# EGADE BUSINESS SCHOOL

# %%
xx

# %% [markdown]
# # <font color='#2B17B0'>Indice de Precios y Cotizaciones - "IPC" S&P BMV -</font>

# %% [markdown]
# > _"El S&P/BMV IPC busca medir el desempeño de las acciones de mayor tamaño y liquidez listadas en la BMV. Su objetivo es proporcionar un índice amplio, representativo, que abarque el mercado bursátil mexicano. Los componentes del índice son ponderados por capitalización de mercado modificada, sujetos a requisitos de diversificación."_<br><br>https://www.spglobal.com/spdji/es/indices/equity/sp-bmv-ipc/#overview

# %% [markdown]
# ### Universo
# > "_Los constituyentes deben de ser acciones listadas en la BMV, excluyendo los Fideicomisos de Inversión en Bienes Raíces (FIBRAS) y los Fideicomisos hipotecarios._"

# %% [markdown]
# ### Historial de Operación
# > _"Deben de cumplir con el siguiente criterio:"_
# > * Las acciones deben de tener un historial de negociación por lo menos de tres meses
# > * Las acciones deberion de haber operado por lo menos en el 95% de los días de los últimos seis meses
# > * Si las acciones tienen menos de seis meses de historial, se aplica al 95% de los días operados

# %% [markdown]
# |Emisora|Ticker|Ticker Y!F|
# |:-|:-|:-|
# |"Indice de Precios y Cotizaciones"|IPC|^MXX|
# |Alfa A|ALFAA|ALFAA.MX|
# |Alsea A|ALSEA|ALSEA.MX|
# |America Movil  B|AMXB|AMXB.MX|
# |Arca Continental|AC|AC.MX|
# |Banco del Bajio|BBAJIOO|BBAJIOO.MX|
# |Becle |CUERVO|CUERVO.MX|
# |Bolsa Mexicana de Valores |BOLSAA|BOLSAA.MX|
# |Cemex CPO|CEMEXCPO|CEMEXCPO.MX|
# |Coca-Cola Femsa  UBL|KOFUBL|KOFUBL.MX|
# |Controladora Vuela Compania de Aviacion |VOLARA|VOLARA.MX|
# |Corporacion Inmobiliaria VestaB. |VESTA|VESTA.MX|
# |El Puerto de Liverpool |LIVEPOLC-1|LIVEPOLC-1.MX|
# |Fomento Economico Mexicano |FEMSAUBD|FEMSAUBD.MX|
# |Genomma Lab Internacional |LABB|LABB.MX|
# |Gentera |GENTERA|GENTERA.MX|
# |Gruma SAB B|GRUMAB|GRUMAB.MX|
# |Grupo Aeroportuario del Centro NorteB. |OMAB|OMAB.MX|
# |Grupo Aeroportuario del PacificoB. |GAPB|GAPB.MX|
# |Grupo Aeroportuario del Sureste  B|ASURB|ASURB.MX|
# |Grupo Bimbo S.A.B.|BIMBOA|BIMBOA.MX|
# |Grupo Carso |GCARSOA1|GCARSOA1.MX|
# |Grupo Cementos de Chihuahua |GCC|GCC.MX|
# |Grupo Elektra |ELEKTRA|ELEKTRA.MX|
# |Grupo Financiero Banorte O|GFNORTEO|GFNORTEO.MX|
# |Grupo Financiero Inbursa O|GFINBURO|GFINBURO.MX|
# |Grupo Mexico  B|GMEXICOB|GMEXICOB.MX|
# |Grupo Televisa  CPO|TLEVISACPO|TLEVISACPO.MX|
# |Industrias Penoles|PE&OLES|PE&OLES.MX|
# |Kimberly Clark de Mexico  A|KIMBERA|KIMBERA.MX|
# |Megacable Holdings |MEGACPO|MEGACPO.MX|
# |ORBIA ADVANCE CORPORATION |ORBIA|ORBIA.MX|
# |Promotora y Operadora de Infraestructura |PINFRA|PINFRA.MX|
# |Qualitas Controladora|Q|Q.MX|
# |Regional |RA|RA.MX|
# |Walmart de Mexico |WALMEX|WALMEX.MX|

# %% [markdown]
# # <font color='#2B17B0'>Precios Yahoo Finance</font>

# %% [markdown]
# ### Como obtener los precios de Y!Finance?

# %%
https://query1.finance.yahoo.com/v7/finance/download/CEMEXCPO.MX?period1=1653862375&period2=1685405575&interval=1d&events=history&includeAdjustedClose=true
https://query1.finance.yahoo.com/v7/finance/download/CEMEXCPO.MX?period1=1590710400&period2=1685318400&interval=1d&events=history&includeAdjustedClose=true

# %% [markdown]
# ## <font color='#2B17B0'>UNIX Epoch Time</font>

# %% [markdown]
# > _"Son los segundos que han pasado a partir de las 0:00:00hrs del 1 de enero, 1970"_

# %% [markdown]
# ### Importar librería datetime

# %%
import datetime

# %% [markdown]
# ### Comparar los timestamps de los links

# %%
datetime.datetime.fromtimestamp(1653862375)
# Out:
# datetime.datetime(2022, 5, 29, 17, 12, 55)

# %%
datetime.datetime.fromtimestamp(1685405575)
# Out:
# datetime.datetime(2023, 5, 29, 18, 12, 55)

# %%
datetime.datetime.fromtimestamp(1590710400)
# Out:
# datetime.datetime(2020, 5, 28, 19, 0)

# %% [markdown]
# ### Epoch 0

# %%
datetime.datetime.fromtimestamp(0)
# Out:
# datetime.datetime(1969, 12, 31, 18, 0)

# %%
datetime.datetime.utcfromtimestamp(0)
# Out:
# datetime.datetime(1970, 1, 1, 0, 0)

# %% [markdown]
# ### Tiempo Universal Coordinado / Coordinated Universal Time (UTC): Stándard de tiempo en el mundo

# %% [markdown]
# UTC es un estándar de tiempo utilizado para sincronizar/coordinar los centros de tiempo alrededor del mundo.  Se utiliza el promedio de dos componentes:
# 1. Hora Atómica Internacional (**TAI**):  Es una escala de tiempo que combina los resultados de 400 relojes atómicos de gran precisión alrededor del mundo
# 1. Hora Universal (**UT1**):  También conocido como tiempo astronómico o solar referente a la rotación de la tierra.  Compara el paso marcado por **TAI** y la duración actual de un día en la tierra.

# %% [markdown]
# ### UTC es un estándard no una zona horaria
# GMT es la Zona Horaria de Greenwich.

# %% [markdown]
# ## <font color='#2B17B0'>Crear función para obtener precios de acciones</font>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://query1.finance.yahoo.com/v7/finance/download/AC.MX?period1=1653862375&period2=1685405575&interval=1d&events=history&includeAdjustedClose=true'

# %%
pd.read_csv(url)
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 0    2022-05-30  134.029999  134.289993  132.059998  133.050003  127.997726  \
# 1    2022-05-31  133.330002  134.630005  131.020004  133.789993  128.709625
# 2    2022-06-01  131.570007  133.000000  129.449997  131.070007  126.092918
# 3    2022-06-02  131.070007  132.380005  126.209999  128.360001  123.485817
# 4    2022-06-03  128.410004  132.850006  126.660004  130.990005  126.015953
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-05-23  175.500000  177.990005  172.020004  172.360001  172.360001
# 248  2023-05-24  173.970001  179.759995  172.199997  175.399994  175.399994
# 249  2023-05-25  174.880005  178.860001  173.679993  175.000000  175.000000
# 250  2023-05-26  176.199997  179.000000  174.460007  176.399994  176.399994
# 251  2023-05-29  176.520004  181.789993  176.500000  180.029999  180.029999
#
#         Volume
# 0     410640.0
# 1    4156392.0
# 2    2139660.0
# 3    1760147.0
# 4    1632389.0
# ..         ...
# 247  1876583.0
# 248  2634214.0
# 249  2436279.0
# 250  1791133.0
# 251   782453.0
#
# [252 rows x 7 columns]

# %%
datetime.datetime.strptime(fecha1, "%Y-%m-%d").strftime('%s')
# Out:
# '1685340000'

# %% [markdown]
# ### Utilizar f String

# %%
accion = 'CEMEXCPO.MX'
fecha0 = '2020-01-01'
fecha1 = '2023-05-29'

fecha0 = datetime.datetime.strptime(fecha0, "%Y-%m-%d").strftime('%s')
fecha1 = datetime.datetime.strptime(fecha1, "%Y-%m-%d").strftime('%s')

url = f'https://query1.finance.yahoo.com/v7/finance/download/{accion}?period1={fecha0}&period2={fecha1}&interval=1d&events=history&includeAdjustedClose=true'

# %% [markdown]
# ### APORTACION DE VICTOR MACHUCA:  ERROR WINDOWS
# Comentó Victor que de las líneas `5` y `6` de la celda anterior le generó error en Windows.  El error es al convertir el objeto de DateTime a epoch `.strftime('%s')`.<br><br>
#
# Código de la clase:<br>
# `fecha0 = datetime.datetime.strptime(fecha0, "%Y-%m-%d").strftime('%s')` <br><br>
# Solución de Victor:<br>
# `import time`<br>
# `fecha0 = datetime.datetime.strptime(fecha0, "%Y-%m-%d")`<br>
# `fecha0 = int(time.mktime(fecha0.timetuple()))`
#
# Lo mismo aplicaría para `fecha1`

# %%
cemex = pd.read_csv(url)

# %% [markdown]
# ### Fechas a Epoch Timestamp

# %%
datetime.datetime.strptime(fecha1, "%Y-%m-%d").strftime('%s')
# Out:
# '1685340000'

# %% [markdown]
# ### Indexar columna `Date`

# %%
cemex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       857 non-null    object
#  1   Open       856 non-null    float64
#  2   High       856 non-null    float64
#  3   Low        856 non-null    float64
#  4   Close      856 non-null    float64
#  5   Adj Close  856 non-null    float64
#  6   Volume     856 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 47.0+ KB

# %%
pd.to_datetime(cemex['Date'])
# Out:
# 0     2020-01-02
# 1     2020-01-03
# 2     2020-01-06
# 3     2020-01-07
# 4     2020-01-08
#          ...
# 852   2023-05-22
# 853   2023-05-23
# 854   2023-05-24
# 855   2023-05-25
# 856   2023-05-26
# Name: Date, Length: 857, dtype: datetime64[ns]

# %%
cemex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       857 non-null    datetime64[ns]
#  1   Open       856 non-null    float64
#  2   High       856 non-null    float64
#  3   Low        856 non-null    float64
#  4   Close      856 non-null    float64
#  5   Adj Close  856 non-null    float64
#  6   Volume     856 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 47.0 KB

# %%
cemex['Date'] = pd.to_datetime(cemex['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 cemex['Date'] = pd.to_datetime(cemex['Date'])
# ----> 2 cemex.set_index(inplace=True)
#
# TypeError: DataFrame.set_index() missing 1 required positional argument: 'keys'

# %%
cemex['Date'].set_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 cemex['Date'].set_index(inplace=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
cemex.set_index(cemex['Date'], inplace=True)

# %%
cemex.sort_index(inplace=True)

# %%
cemex
# Out:
#                  Date   Open   High    Low  Close  Adj Close      Volume
# Date
# 2020-01-02 2020-01-02   7.17   7.28   7.12   7.16       7.16  38630092.0
# 2020-01-03 2020-01-03   7.13   7.23   7.13   7.19       7.19  19123326.0
# 2020-01-06 2020-01-06   7.15   7.22   7.07   7.20       7.20  13614055.0
# 2020-01-07 2020-01-07   7.16   7.20   7.01   7.07       7.07  26746909.0
# 2020-01-08 2020-01-08   7.10   7.22   7.05   7.20       7.20  29105133.0
# ...               ...    ...    ...    ...    ...        ...         ...
# 2023-05-22 2023-05-22  11.51  11.64  11.29  11.33      11.33  36863319.0
# 2023-05-23 2023-05-23  11.30  11.42  11.01  11.08      11.08  38194718.0
# 2023-05-24 2023-05-24  11.01  11.01  10.70  11.00      11.00  50302268.0
# 2023-05-25 2023-05-25  11.03  11.17  10.93  11.10      11.10  43339408.0
# 2023-05-26 2023-05-26  11.10  11.24  10.94  11.09      11.09  36902139.0
#
# [857 rows x 7 columns]

# %% [markdown]
# ## Función `precios`

# %% [markdown]
# ### Arreglar datos obtenidos de Yahoo Finance:

# %% [markdown]
# 1. Transformar columna `Date` de `Object` a `DateTime`
# 1. Indexar columna `Date`
# 1. "Sortear" fechas de manera ascendente
# 1. Quizá cambiar títulos a los `labels`

# %%
def precios(accion, fecha0, fecha1):
    
    fecha0 = datetime.datetime.strptime(fecha0, "%Y-%m-%d").strftime('%s')
    fecha1 = datetime.datetime.strptime(fecha1, "%Y-%m-%d").strftime('%s')
    
    url = f'https://query1.finance.yahoo.com/v7/finance/download/{accion}?period1={fecha0}&period2={fecha1}&interval=1d&events=history&includeAdjustedClose=true'
    
    df = pd.read_csv(url)
    nombre_columnas = {
        'Date': 'fecha',
        'Open': 'apertura',
        'High': 'maximo',
        'Low': 'minimo',
        'Close': 'cierre',
        'Adj Close': 'cierre_ajustado'
    }
    
    df.rename(columns=nombre_columnas, inplace=True)
    
    df['fecha'] = pd.to_datetime(df['fecha'])
    df.set_index(df['fecha'], inplace=True)
    df.sort_index(inplace=True)
    
    return df

# %%
gruma = precios('grumab.mx', '2022-01-01', '2023-05-29')

# %%
gruma
# Out:
#                 fecha    apertura      maximo      minimo      cierre
# fecha
# 2022-01-03 2022-01-03  261.690002  263.989990  260.320007  262.600006  \
# 2022-01-04 2022-01-04  261.299988  263.000000  260.130005  262.799988
# 2022-01-05 2022-01-05  260.839996  262.000000  257.869995  259.980011
# 2022-01-06 2022-01-06  258.000000  260.549988  252.160004  258.100006
# 2022-01-07 2022-01-07  256.799988  259.980011  255.199997  255.899994
# ...               ...         ...         ...         ...         ...
# 2023-05-22 2023-05-22  272.029999  274.420013  265.109985  266.000000
# 2023-05-23 2023-05-23  266.429993  270.140015  262.089996  262.500000
# 2023-05-24 2023-05-24  263.200012  265.019989  257.250000  263.000000
# 2023-05-25 2023-05-25  263.440002  268.489990  262.040009  262.500000
# 2023-05-26 2023-05-26  262.850006  280.000000  262.589996  276.750000
#
#             cierre_ajustado     Volume
# fecha
# 2022-01-03       253.880295    80129.0
# 2022-01-04       254.073669   296876.0
# 2022-01-05       252.596848   852158.0
# 2022-01-06       250.770218  1091891.0
# 2022-01-07       248.632690  1024239.0
# ...                     ...        ...
# 2023-05-22       266.000000  1092786.0
# 2023-05-23       262.500000   483428.0
# 2023-05-24       263.000000  1881009.0
# 2023-05-25       262.500000   487415.0
# 2023-05-26       276.750000  1621496.0
#
# [352 rows x 7 columns]

# %% [markdown]
# ## Guardar función en nuestra librería y recargarlas en automático:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from herramientas import herramientas_financieras as hf

# %% [markdown]
# ## Crear función para calcular retornos logarítmicos

# %%
gruma['ret_ln'] = np.log(gruma['cierre_ajustado'] / gruma['cierre_ajustado'].shift(1))

# %%
gruma
# Out:
#                 fecha    apertura      maximo      minimo      cierre
# fecha
# 2022-01-03 2022-01-03  261.690002  263.989990  260.320007  262.600006  \
# 2022-01-04 2022-01-04  261.299988  263.000000  260.130005  262.799988
# 2022-01-05 2022-01-05  260.839996  262.000000  257.869995  259.980011
# 2022-01-06 2022-01-06  258.000000  260.549988  252.160004  258.100006
# 2022-01-07 2022-01-07  256.799988  259.980011  255.199997  255.899994
# ...               ...         ...         ...         ...         ...
# 2023-05-22 2023-05-22  272.029999  274.420013  265.109985  266.000000
# 2023-05-23 2023-05-23  266.429993  270.140015  262.089996  262.500000
# 2023-05-24 2023-05-24  263.200012  265.019989  257.250000  263.000000
# 2023-05-25 2023-05-25  263.440002  268.489990  262.040009  262.500000
# 2023-05-26 2023-05-26  262.850006  280.000000  262.589996  276.750000
#
#             cierre_ajustado     Volume    ret_ln
# fecha
# 2022-01-03       253.880295    80129.0       NaN
# 2022-01-04       254.073669   296876.0  0.000761
# 2022-01-05       252.596848   852158.0 -0.005830
# 2022-01-06       250.770218  1091891.0 -0.007258
# 2022-01-07       248.632690  1024239.0 -0.008560
# ...                     ...        ...       ...
# 2023-05-22       266.000000  1092786.0 -0.022894
# 2023-05-23       262.500000   483428.0 -0.013245
# 2023-05-24       263.000000  1881009.0  0.001903
# 2023-05-25       262.500000   487415.0 -0.001903
# 2023-05-26       276.750000  1621496.0  0.052863
#
# [352 rows x 8 columns]

# %%
def ret_ln(df, columna):
    """
    Regresa un DataFrame con el retorno LN
    
    PARAMETROS:
    -------
    df = DataFrame al que se calcula el LN
    columna = Nombre de la columna
    """
    
    df['ret_ln'] = np.log(df[columna] / df[columna].shift(1))
    
    return df['ret_ln']

# %%
del gruma['ret_ln']

# %%
gruma
# Out:
#                 fecha    apertura      maximo      minimo      cierre
# fecha
# 2022-01-03 2022-01-03  261.690002  263.989990  260.320007  262.600006  \
# 2022-01-04 2022-01-04  261.299988  263.000000  260.130005  262.799988
# 2022-01-05 2022-01-05  260.839996  262.000000  257.869995  259.980011
# 2022-01-06 2022-01-06  258.000000  260.549988  252.160004  258.100006
# 2022-01-07 2022-01-07  256.799988  259.980011  255.199997  255.899994
# ...               ...         ...         ...         ...         ...
# 2023-05-22 2023-05-22  272.029999  274.420013  265.109985  266.000000
# 2023-05-23 2023-05-23  266.429993  270.140015  262.089996  262.500000
# 2023-05-24 2023-05-24  263.200012  265.019989  257.250000  263.000000
# 2023-05-25 2023-05-25  263.440002  268.489990  262.040009  262.500000
# 2023-05-26 2023-05-26  262.850006  280.000000  262.589996  276.750000
#
#             cierre_ajustado     Volume
# fecha
# 2022-01-03       253.880295    80129.0
# 2022-01-04       254.073669   296876.0
# 2022-01-05       252.596848   852158.0
# 2022-01-06       250.770218  1091891.0
# 2022-01-07       248.632690  1024239.0
# ...                     ...        ...
# 2023-05-22       266.000000  1092786.0
# 2023-05-23       262.500000   483428.0
# 2023-05-24       263.000000  1881009.0
# 2023-05-25       262.500000   487415.0
# 2023-05-26       276.750000  1621496.0
#
# [352 rows x 7 columns]

# %%
gruma['ret_ln'] = ret_ln(gruma, 'cierre_ajustado')
gruma
# Out:
#                 fecha    apertura      maximo      minimo      cierre
# fecha
# 2022-01-03 2022-01-03  261.690002  263.989990  260.320007  262.600006  \
# 2022-01-04 2022-01-04  261.299988  263.000000  260.130005  262.799988
# 2022-01-05 2022-01-05  260.839996  262.000000  257.869995  259.980011
# 2022-01-06 2022-01-06  258.000000  260.549988  252.160004  258.100006
# 2022-01-07 2022-01-07  256.799988  259.980011  255.199997  255.899994
# ...               ...         ...         ...         ...         ...
# 2023-05-22 2023-05-22  272.029999  274.420013  265.109985  266.000000
# 2023-05-23 2023-05-23  266.429993  270.140015  262.089996  262.500000
# 2023-05-24 2023-05-24  263.200012  265.019989  257.250000  263.000000
# 2023-05-25 2023-05-25  263.440002  268.489990  262.040009  262.500000
# 2023-05-26 2023-05-26  262.850006  280.000000  262.589996  276.750000
#
#             cierre_ajustado     Volume    ret_ln
# fecha
# 2022-01-03       253.880295    80129.0       NaN
# 2022-01-04       254.073669   296876.0  0.000761
# 2022-01-05       252.596848   852158.0 -0.005830
# 2022-01-06       250.770218  1091891.0 -0.007258
# 2022-01-07       248.632690  1024239.0 -0.008560
# ...                     ...        ...       ...
# 2023-05-22       266.000000  1092786.0 -0.022894
# 2023-05-23       262.500000   483428.0 -0.013245
# 2023-05-24       263.000000  1881009.0  0.001903
# 2023-05-25       262.500000   487415.0 -0.001903
# 2023-05-26       276.750000  1621496.0  0.052863
#
# [352 rows x 8 columns]

# %%
gruma['ret_ln'].plot();

# %%
import matplotlib.pyplot as plt

# %%
gruma['ret_ln'].plot()
plt.axhline((2*gruma['ret_ln'].std()), c='r')
plt.axhline((-2*gruma['ret_ln'].std()), c='r');

# %% [markdown]
# ## Comparar 2 o más acciones

# %% [markdown]
# ### Crear DataFrame con 2 o más precios de cierre de diferentes acciones

# %% [markdown]
# Pasos a seguir
# 1. Crear una lista con las acciones de interés
# 1. Crea un df vacío
# 1. Generar un for loop para cada elemento de la lista
#     1. Llamar a la función precios
#     1. Asignar al dataframe vacío la columna de precio ajustado, con el nombre de la acción
#     1. Borrar el dataframe donde se bajó los precios de la acción en turno

# %%
lista_acciones = ['^MXX', 'AC.MX', 'BIMBOA.MX', 'PE&OLES.MX', 'TLEVISACPO.MX']
cierres = pd.DataFrame()

for accion in lista_acciones:
    df = precios(accion, '2020-01-01', '2023-05-29')
    cierres[accion] = df['cierre_ajustado']
    
    del df

# %%
cierres
# Out:
#                     ^MXX       AC.MX  BIMBOA.MX  PE&OLES.MX  TLEVISACPO.MX
# fecha
# 2020-01-02  44437.230469   86.612556  33.092861  206.533569      43.503357
# 2020-01-03  44624.851563   87.385811  33.102219  210.751602      43.599754
# 2020-01-06  44495.300781   87.058678  33.247280  212.450806      42.862324
# 2020-01-07  44157.808594   87.878647  32.802734  212.130951      42.018864
# 2020-01-08  44470.910156   87.589737  32.774666  209.901993      42.481560
# ...                  ...         ...        ...         ...            ...
# 2023-05-22  53466.320313  175.300003  90.540001  265.190002      16.855259
# 2023-05-23  53123.218750  172.360001  90.830002  251.050003      16.747526
# 2023-05-24  53393.398438  175.399994  92.470001  257.809998      16.541855
# 2023-05-25  53744.679688  175.000000  93.489998  260.279999      16.267628
# 2023-05-26  54025.449219  176.399994  93.720001  268.200012      16.629999
#
# [857 rows x 5 columns]

# %% [markdown]
# ### Visualizar dataframe

# %%
cierres.plot(title='Gráfica sin utilidad');

# %%
cierres
# Out:
#                     ^MXX       AC.MX  BIMBOA.MX  PE&OLES.MX  TLEVISACPO.MX
# fecha
# 2020-01-02  44437.230469   86.612556  33.092861  206.533569      43.503357
# 2020-01-03  44624.851563   87.385811  33.102219  210.751602      43.599754
# 2020-01-06  44495.300781   87.058678  33.247280  212.450806      42.862324
# 2020-01-07  44157.808594   87.878647  32.802734  212.130951      42.018864
# 2020-01-08  44470.910156   87.589737  32.774666  209.901993      42.481560
# ...                  ...         ...        ...         ...            ...
# 2023-05-22  53466.320313  175.300003  90.540001  265.190002      16.855259
# 2023-05-23  53123.218750  172.360001  90.830002  251.050003      16.747526
# 2023-05-24  53393.398438  175.399994  92.470001  257.809998      16.541855
# 2023-05-25  53744.679688  175.000000  93.489998  260.279999      16.267628
# 2023-05-26  54025.449219  176.399994  93.720001  268.200012      16.629999
#
# [857 rows x 5 columns]

# %% [markdown]
# ### Normalizado de series de tiempo: Comparar 2 o más acciones

# %%
normalizacion_base1 = cierres / cierres.iloc[0,:]
normalizacion_base1
# Out:
#                 ^MXX     AC.MX  BIMBOA.MX  PE&OLES.MX  TLEVISACPO.MX
# fecha
# 2020-01-02  1.000000  1.000000   1.000000    1.000000       1.000000
# 2020-01-03  1.004222  1.008928   1.000283    1.020423       1.002216
# 2020-01-06  1.001307  1.005151   1.004666    1.028650       0.985265
# 2020-01-07  0.993712  1.014618   0.991233    1.027102       0.965876
# 2020-01-08  1.000758  1.011282   0.990385    1.016309       0.976512
# ...              ...       ...        ...         ...            ...
# 2023-05-22  1.203188  2.023956   2.735938    1.284004       0.387447
# 2023-05-23  1.195466  1.990012   2.744701    1.215541       0.384971
# 2023-05-24  1.201546  2.025110   2.794258    1.248272       0.380243
# 2023-05-25  1.209452  2.020492   2.825081    1.260231       0.373940
# 2023-05-26  1.215770  2.036656   2.832031    1.298578       0.382269
#
# [857 rows x 5 columns]

# %%
normalizacion_base1.plot()
# Out:
# <Axes: xlabel='fecha'>

# %%
normalizacion_base0 = cierres / cierres.iloc[0,:] - 1
normalizacion_base0
# Out:
#                 ^MXX     AC.MX  BIMBOA.MX  PE&OLES.MX  TLEVISACPO.MX
# fecha
# 2020-01-02  0.000000  0.000000   0.000000    0.000000       0.000000
# 2020-01-03  0.004222  0.008928   0.000283    0.020423       0.002216
# 2020-01-06  0.001307  0.005151   0.004666    0.028650      -0.014735
# 2020-01-07 -0.006288  0.014618  -0.008767    0.027102      -0.034124
# 2020-01-08  0.000758  0.011282  -0.009615    0.016309      -0.023488
# ...              ...       ...        ...         ...            ...
# 2023-05-22  0.203188  1.023956   1.735938    0.284004      -0.612553
# 2023-05-23  0.195466  0.990012   1.744701    0.215541      -0.615029
# 2023-05-24  0.201546  1.025110   1.794258    0.248272      -0.619757
# 2023-05-25  0.209452  1.020492   1.825081    0.260231      -0.626060
# 2023-05-26  0.215770  1.036656   1.832031    0.298578      -0.617731
#
# [857 rows x 5 columns]

# %%
normalizacion_base0.plot();

# %% [markdown]
# # <font color='#2B17B0'>Análisis técnico y análisis fundamental</font>

# %% [markdown]
# ## Diferencia entre los dos tipos de análisis

# %% [markdown]
# ## Análisis técnico

# %% [markdown]
# ### Tipos de gráficas
# Ir a trading view

# %% [markdown]
# ## Algoritmo Promedios Móviles

# %% [markdown]
# Un promedio móvil es una técnica que calcula el promedio de un conjunto de datos a lo largo de un período específico, que se actualiza constantemente a medida que pasa el tiempo. Por ejemplo, en el caso de los precios de cierre de una acción, un promedio móvil de 20 días calcula el promedio de los precios de cierre de los últimos 20 días. Con cada día que pasa, se elimina el dato correspondiente al día más antiguo de los 20 y se incorpora el precio del día más reciente. De esta forma, el promedio móvil siempre refleja el precio promedio de las últimos 20 días.<br><br>
#
# Los PM se basan en la idea que los precios:
# * Reflejan unicamente el *sentir* del mercado en ese dia.
# * No reflejan el verdadero precio del activo.
# * Todos los días se corrigen los precios para llegar al precio real.
# * Al promediar los precios de cierre de los últimos "n" dias, se llega a un precio más real.
# <br><br>
# Comentarios:
# * Uno de los indicadores técnicos más utilizados.
# * Muchos sistemas basados en estrategias de "trend-following", lo utilizan como base de sus algorítmos.
# * Muy fácil de cuantificar y probar.
# * Las reglas de los promedios móviles son fácil de programar y generar señales de compra venta.
# <br><br>
# El PM se calcula de la siguiente manera:
# * Generamos dos promedios móviles vectorizados, donde generalmente el 1er promedio móvil (PM1) es de corto plazo (3 a 30 dias) y el 2do promédio móvil (PM2) es de mediano plazo (2, 3 hasta 12 meses).
# <br><br>
#
# Nuestra estrategia consiste en tomar posiciones "long" (comprar) o "short" (vender) al cruce de los PMs:
# * Long: PM1 > PM2
# * Short: PM1 < PM2
# <br><br>
# Para calcular los PMs, utilizaremos el "método" .rolling(window).mean( ).
# con los siguientes datos:

# %%
accion = 'cemexcpo.mx'
pm1 = 13
pm2 = 55

df = precios(accion, '2020-01-01', '2023-05-29')

# %%
df
# Out:
#                 fecha  apertura  maximo  minimo  cierre  cierre_ajustado
# fecha
# 2020-01-02 2020-01-02      7.17    7.28    7.12    7.16             7.16  \
# 2020-01-03 2020-01-03      7.13    7.23    7.13    7.19             7.19
# 2020-01-06 2020-01-06      7.15    7.22    7.07    7.20             7.20
# 2020-01-07 2020-01-07      7.16    7.20    7.01    7.07             7.07
# 2020-01-08 2020-01-08      7.10    7.22    7.05    7.20             7.20
# ...               ...       ...     ...     ...     ...              ...
# 2023-05-22 2023-05-22     11.51   11.64   11.29   11.33            11.33
# 2023-05-23 2023-05-23     11.30   11.42   11.01   11.08            11.08
# 2023-05-24 2023-05-24     11.01   11.01   10.70   11.00            11.00
# 2023-05-25 2023-05-25     11.03   11.17   10.93   11.10            11.10
# 2023-05-26 2023-05-26     11.10   11.24   10.94   11.09            11.09
#
#                 Volume
# fecha
# 2020-01-02  38630092.0
# 2020-01-03  19123326.0
# 2020-01-06  13614055.0
# 2020-01-07  26746909.0
# 2020-01-08  29105133.0
# ...                ...
# 2023-05-22  36863319.0
# 2023-05-23  38194718.0
# 2023-05-24  50302268.0
# 2023-05-25  43339408.0
# 2023-05-26  36902139.0
#
# [857 rows x 7 columns]

# %% [markdown]
# ### Cálculo de los promedios móviles

# %% [markdown]
# Referencia sobre la función `rolling` de pandas:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html

# %%
df.dropna(inplace=True)
df['pm1'] = df['cierre_ajustado'].rolling(pm1).mean()
df['pm2'] = df['cierre_ajustado'].rolling(pm2).mean()

# %% [markdown]
# ### Visualización

# %%
df.drop(['fecha', 'apertura', 'maximo', 'minimo', 'cierre', 'Volume'], axis=1, inplace=True)

# %%
df.head(20)
# Out:
#             cierre_ajustado       pm1  pm2
# fecha
# 2020-01-02            7.160       NaN  NaN
# 2020-01-03            7.190       NaN  NaN
# 2020-01-06            7.200       NaN  NaN
# 2020-01-07            7.070       NaN  NaN
# 2020-01-08            7.200       NaN  NaN
# 2020-01-09            7.100       NaN  NaN
# 2020-01-10            7.180       NaN  NaN
# 2020-01-13            7.150       NaN  NaN
# 2020-01-14            7.120       NaN  NaN
# 2020-01-15            6.950       NaN  NaN
# 2020-01-16            7.290       NaN  NaN
# 2020-01-17            7.820       NaN  NaN
# 2020-01-20            7.700  7.240769  NaN
# 2020-01-21            7.710  7.283077  NaN
# 2020-01-22            7.890  7.336923  NaN
# 2020-01-23            7.880  7.389231  NaN
# 2020-01-24            7.870  7.450769  NaN
# 2020-01-27            7.785  7.495769  NaN
# 2020-01-28            8.050  7.568846  NaN
# 2020-01-29            7.950  7.628077  NaN

# %%
df.plot();

# %% [markdown]
# ### Calcular posicion en el mercado

# %% [markdown]
# Ventas en corto permitidas:
# La estrategia consiste en tomar posiciones "long" o "short" al cruce de los PMs:
# * Long: PM1 > PM2 $\longrightarrow$ __1__
# * Short: PM1 < PM2 $\longrightarrow$ __-1__
#
# Ventas en corto no permitidas:
# * Long: PM1 > PM2 $\longrightarrow$ __1__
# * Out:   PM1 < PM2 $\longrightarrow$ **0**
#
# El utilizar números nos permite:
# * Visualizar posición en el mercado de acuerdo a los crueces de lospromedios móviles
# * Calcular los retornos de de la estrategia

# %% [markdown]
# #### Cálculo de posición del mercado utilizando ventas en corto

# %% [markdown]
# Referencia sobre función `where` de numpy:
# https://numpy.org/doc/stable/reference/generated/numpy.where.html

# %%
long = 1
short = -1

df['posicion'] = np.where(df['pm1']>df['pm2'], long, short)

# %% [markdown]
# #### Visualizar posiciones en el mercado

# %%
df
# Out:
#             cierre_ajustado        pm1        pm2  posicion
# fecha
# 2020-01-02             7.16        NaN        NaN        -1
# 2020-01-03             7.19        NaN        NaN        -1
# 2020-01-06             7.20        NaN        NaN        -1
# 2020-01-07             7.07        NaN        NaN        -1
# 2020-01-08             7.20        NaN        NaN        -1
# ...                     ...        ...        ...       ...
# 2023-05-22            11.33  11.589231  10.351455         1
# 2023-05-23            11.08  11.570000  10.387455         1
# 2023-05-24            11.00  11.516154  10.416727         1
# 2023-05-25            11.10  11.473077  10.440545         1
# 2023-05-26            11.09  11.406923  10.457273         1
#
# [856 rows x 4 columns]

# %%
df[['cierre_ajustado', 'pm1', 'pm2']].plot()
df['posicion'].plot()
# Out:
# <Axes: xlabel='fecha'>

# %%
df['ret_ln'] = ret_ln(df, 'cierre_ajustado')

# %%
df.dropna(inplace=True)
df
# Out:
#             cierre_ajustado        pm1        pm2  posicion    ret_ln
# fecha
# 2020-03-20             4.32   5.497692   6.905455        -1 -0.056258
# 2020-03-23             4.24   5.316923   6.852364        -1 -0.018692
# 2020-03-24             4.47   5.143077   6.802909        -1  0.052825
# 2020-03-25             4.29   4.991538   6.750000        -1 -0.041102
# 2020-03-26             4.61   4.893846   6.705273        -1  0.071941
# ...                     ...        ...        ...       ...       ...
# 2023-05-22            11.33  11.589231  10.351455         1 -0.014893
# 2023-05-23            11.08  11.570000  10.387455         1 -0.022312
# 2023-05-24            11.00  11.516154  10.416727         1 -0.007246
# 2023-05-25            11.10  11.473077  10.440545         1  0.009050
# 2023-05-26            11.09  11.406923  10.457273         1 -0.000901
#
# [802 rows x 5 columns]

# %%
df.head(50)
# Out:
#             cierre_ajustado       pm1       pm2  posicion    ret_ln
# fecha
# 2020-03-20             4.32  5.497692  6.905455        -1 -0.056258
# 2020-03-23             4.24  5.316923  6.852364        -1 -0.018692
# 2020-03-24             4.47  5.143077  6.802909        -1  0.052825
# 2020-03-25             4.29  4.991538  6.750000        -1 -0.041102
# 2020-03-26             4.61  4.893846  6.705273        -1  0.071941
# 2020-03-27             4.29  4.809231  6.652364        -1 -0.071941
# 2020-03-30             4.34  4.706923  6.602182        -1  0.011588
# 2020-03-31             4.93  4.651538  6.561273        -1  0.127465
# 2020-04-01             4.59  4.602308  6.514727        -1 -0.071459
# 2020-04-02             4.46  4.532308  6.466364        -1 -0.028731
# 2020-04-03             4.21  4.466154  6.416545        -1 -0.057686
# 2020-04-06             4.61  4.456154  6.367818        -1  0.090765
# 2020-04-07             4.93  4.483846  6.315273        -1  0.067111
# 2020-04-08             5.01  4.536923  6.266364        -1  0.016097
# 2020-04-13             5.09  4.602308  6.218727        -1  0.015842
# 2020-04-14             4.85  4.631538  6.163455        -1 -0.048299
# 2020-04-15             4.84  4.673846  6.108182        -1 -0.002064
# 2020-04-16             4.72  4.682308  6.050909        -1 -0.025106
# 2020-04-17             5.05  4.740769  6.001182        -1  0.067579
# 2020-04-20             4.97  4.789231  5.945182        -1 -0.015968
# 2020-04-21             4.68  4.770000  5.885727        -1 -0.060122
# 2020-04-22             4.69  4.777692  5.828273        -1  0.002134
# 2020-04-23             4.67  4.793846  5.775091        -1 -0.004274
# 2020-04-24             4.63  4.826154  5.714818        -1 -0.008602
# 2020-04-27             4.68  4.831538  5.659000        -1  0.010741
# 2020-04-28             5.05  4.840769  5.609909        -1  0.076090
# 2020-04-29             5.22  4.856923  5.563182        -1  0.033109
# 2020-04-30             5.07  4.855385  5.514727        -1 -0.029157
# 2020-05-04             5.13  4.876923  5.461636        -1  0.011765
# 2020-05-05             5.18  4.903077  5.416727        -1  0.009699
# 2020-05-06             5.02  4.926154  5.375636        -1 -0.031375
# 2020-05-07             5.08  4.928462  5.338000        -1  0.011881
# 2020-05-08             5.12  4.940000  5.300909        -1  0.007843
# 2020-05-11             5.13  4.974615  5.266909        -1  0.001951
# 2020-05-12             5.05  5.002308  5.232364        -1 -0.015717
# 2020-05-13             4.64  5.000000  5.189455        -1 -0.084674
# 2020-05-14             4.57  4.995385  5.143455        -1 -0.015201
# 2020-05-15             4.62  4.990769  5.099273        -1  0.010882
# 2020-05-18             4.72  4.965385  5.059636        -1  0.021414
# 2020-05-19             4.65  4.921538  5.027091        -1 -0.014942
# 2020-05-20             4.83  4.903077  5.002727        -1  0.037979
# 2020-05-21             4.87  4.883077  4.976000        -1  0.008247
# 2020-05-22             4.77  4.851538  4.946182        -1 -0.020748
# 2020-05-25             4.77  4.832308  4.913091        -1  0.000000
# 2020-05-26             4.94  4.821538  4.880545        -1  0.035019
# 2020-05-27             5.30  4.835385  4.863091        -1  0.070341
# 2020-05-28             5.29  4.847692  4.852364        -1 -0.001889
# 2020-05-29             5.25  4.863077  4.849818         1 -0.007590
# 2020-06-01             5.33  4.916154  4.843636         1  0.015123
# 2020-06-02             5.82  5.012308  4.846727         1  0.087949

# %%
df['ret_est'] = df['ret_ln'] * df['posicion'].shift(1)

# %%
df
# Out:
#             cierre_ajustado        pm1        pm2  posicion    ret_ln
# fecha
# 2020-03-20             4.32   5.497692   6.905455        -1 -0.056258  \
# 2020-03-23             4.24   5.316923   6.852364        -1 -0.018692
# 2020-03-24             4.47   5.143077   6.802909        -1  0.052825
# 2020-03-25             4.29   4.991538   6.750000        -1 -0.041102
# 2020-03-26             4.61   4.893846   6.705273        -1  0.071941
# ...                     ...        ...        ...       ...       ...
# 2023-05-22            11.33  11.589231  10.351455         1 -0.014893
# 2023-05-23            11.08  11.570000  10.387455         1 -0.022312
# 2023-05-24            11.00  11.516154  10.416727         1 -0.007246
# 2023-05-25            11.10  11.473077  10.440545         1  0.009050
# 2023-05-26            11.09  11.406923  10.457273         1 -0.000901
#
#              ret_est
# fecha
# 2020-03-20       NaN
# 2020-03-23  0.018692
# 2020-03-24 -0.052825
# 2020-03-25  0.041102
# 2020-03-26 -0.071941
# ...              ...
# 2023-05-22 -0.014893
# 2023-05-23 -0.022312
# 2023-05-24 -0.007246
# 2023-05-25  0.009050
# 2023-05-26 -0.000901
#
# [802 rows x 6 columns]

# %%
df[['ret_ln', 'ret_est']].sum()
# Out:
# ret_ln     0.886531
# ret_est    1.300142
# dtype: float64

# %%
np.exp(df[['ret_ln', 'ret_est']].sum())
# Out:
# ret_ln     2.426696
# ret_est    3.669819
# dtype: float64

# %% [markdown]
# ### Retornos del mercado Vs Estrategia PMs

# %% [markdown]
# ### Visualizar desempeño

# %% [markdown]
# ### Balance monetario

# %% [markdown]
# ### Balance: Máximos

# %% [markdown]
# ### Balance: Perdidas

# %% [markdown]
# ### Encontrar pérdida máxima

# %% [markdown]
# Pasos:
# 1. Identificar la mayor pérdida del periodo
# 1. Encontrar la fecha de la mayor pérdida
# 1. Identificar el pico máximo acumulado en la fecha de la mayor perdida
# 1. Identificar el balance en la fecha de la mayor pérdida
# 1. Graficar

# %% [markdown]
# #### dentificar la mayor perdida

# %% [markdown]
# #### Encontrar fecha

# %% [markdown]
# #### Identificar valor del pico máximo en la fecha de la mayor perdida

# %% [markdown]
# #### Identificar balance en la fecha de la mayor pérdida
